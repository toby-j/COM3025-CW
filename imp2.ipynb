# %%
import numpy as np
import pandas as pd
import os
from matplotlib import pyplot as plt
import seaborn as sns
import cv2

# %%
df = pd.read_csv('content/HAM10000_metadata')

# %%
print(df)
# Out:
#          lesion_id      image_id     dx dx_type   age     sex localization  \
# 0      HAM_0000118  ISIC_0027419    bkl   histo  80.0    male        scalp
# 1      HAM_0000118  ISIC_0025030    bkl   histo  80.0    male        scalp
# 2      HAM_0002730  ISIC_0026769    bkl   histo  80.0    male        scalp
# 3      HAM_0002730  ISIC_0025661    bkl   histo  80.0    male        scalp
# 4      HAM_0001466  ISIC_0031633    bkl   histo  75.0    male          ear
# ...            ...           ...    ...     ...   ...     ...          ...
# 10010  HAM_0002867  ISIC_0033084  akiec   histo  40.0    male      abdomen
# 10011  HAM_0002867  ISIC_0033550  akiec   histo  40.0    male      abdomen
# 10012  HAM_0002867  ISIC_0033536  akiec   histo  40.0    male      abdomen
# 10013  HAM_0000239  ISIC_0032854  akiec   histo  80.0    male         face
# 10014  HAM_0003521  ISIC_0032258    mel   histo  70.0  female         back
#
#             dataset
# 0      vidir_modern
# 1      vidir_modern
# 2      vidir_modern
# 3      vidir_modern
# 4      vidir_modern
# ...             ...
# 10010  vidir_modern
# 10011  vidir_modern
# 10012  vidir_modern
# 10013  vidir_modern
# 10014  vidir_modern
#
# [10015 rows x 8 columns]

# %%
df.head()
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization  \
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear
#
#         dataset
# 0  vidir_modern
# 1  vidir_modern
# 2  vidir_modern
# 3  vidir_modern
# 4  vidir_modern

# %%
df.describe()
# Out:
#                age
# count  9958.000000
# mean     51.863828
# std      16.968614
# min       0.000000
# 25%      40.000000
# 50%      50.000000
# 75%      65.000000
# max      85.000000

# %%
lesion_type_dict = {
    'nv': 'Melanocytic nevi',
    'mel': 'Melanoma',
    'bkl': 'Bening keratosis-like lesions',
    'bcc': 'Basal cell carcinoma',
    'akiec': 'Actinic keratoses',
    'vasc': 'Vascular lesions',
    'df': 'Dermatofibroma'
}
raw_images = 'content\HAM10000_images'

# %%
from glob import glob

imageid_path_dict = {os.path.splitext(os.path.basename(x))[0]: x
                     for x in glob(os.path.join(raw_images, '*.jpg'))}

# %%
print({os.path.splitext(os.path.basename(x))[0]: x
                     for x in glob(os.path.join(raw_images, '*.jpg'))})
# Out:
# {'ISIC_0024306': 'content\\HAM10000_images\\ISIC_0024306.jpg', 'ISIC_0024307': 'content\\HAM10000_images\\ISIC_0024307.jpg', 'ISIC_0024308': 'content\\HAM10000_images\\ISIC_0024308.jpg', 'ISIC_0024309': 'content\\HAM10000_images\\ISIC_0024309.jpg', 'ISIC_0024310': 'content\\HAM10000_images\\ISIC_0024310.jpg', 'ISIC_0024311': 'content\\HAM10000_images\\ISIC_0024311.jpg', 'ISIC_0024312': 'content\\HAM10000_images\\ISIC_0024312.jpg', 'ISIC_0024313': 'content\\HAM10000_images\\ISIC_0024313.jpg', 'ISIC_0024314': 'content\\HAM10000_images\\ISIC_0024314.jpg', 'ISIC_0024315': 'content\\HAM10000_images\\ISIC_0024315.jpg', 'ISIC_0024316': 'content\\HAM10000_images\\ISIC_0024316.jpg', 'ISIC_0024317': 'content\\HAM10000_images\\ISIC_0024317.jpg', 'ISIC_0024318': 'content\\HAM10000_images\\ISIC_0024318.jpg', 'ISIC_0024319': 'content\\HAM10000_images\\ISIC_0024319.jpg', 'ISIC_0024320': 'content\\HAM10000_images\\ISIC_0024320.jpg', 'ISIC_0024321': 'content\\HAM10000_images\\ISIC_0024321.jpg', 'ISIC_0024322': 'content\\HAM10000_images\\ISIC_0024322.jpg', 'ISIC_0024323': 'content\\HAM10000_images\\ISIC_0024323.jpg', 'ISIC_0024324': 'content\\HAM10000_images\\ISIC_0024324.jpg', 'ISIC_0024325': 'content\\HAM10000_images\\ISIC_0024325.jpg', 'ISIC_0024326': 'content\\HAM10000_images\\ISIC_0024326.jpg', 'ISIC_0024327': 'content\\HAM10000_images\\ISIC_0024327.jpg', 'ISIC_0024328': 'content\\HAM10000_images\\ISIC_0024328.jpg', 'ISIC_0024329': 'content\\HAM10000_images\\ISIC_0024329.jpg', 'ISIC_0024330': 'content\\HAM10000_images\\ISIC_0024330.jpg', 'ISIC_0024331': 'content\\HAM10000_images\\ISIC_0024331.jpg', 'ISIC_0024332': 'content\\HAM10000_images\\ISIC_0024332.jpg', 'ISIC_0024333': 'content\\HAM10000_images\\ISIC_0024333.jpg', 'ISIC_0024334': 'content\\HAM10000_images\\ISIC_0024334.jpg', 'ISIC_0024335': 'content\\HAM10000_images\\ISIC_0024335.jpg', 'ISIC_0024336': 'content\\HAM10000_images\\ISIC_0024336.jpg', 'ISIC_0024337': 'content\\HAM10000_images\\ISIC_0024337.jpg', 'ISIC_0024338': 'content\\HAM10000_images\\ISIC_0024338.jpg', 'ISIC_0024339': 'content\\HAM10000_images\\ISIC_0024339.jpg', 'ISIC_0024340': 'content\\HAM10000_images\\ISIC_0024340.jpg', 'ISIC_0024341': 'content\\HAM10000_images\\ISIC_0024341.jpg', 'ISIC_0024342': 'content\\HAM10000_images\\ISIC_0024342.jpg', 'ISIC_0024343': 'content\\HAM10000_images\\ISIC_0024343.jpg', 'ISIC_0024344': 'content\\HAM10000_images\\ISIC_0024344.jpg', 'ISIC_0024345': 'content\\HAM10000_images\\ISIC_0024345.jpg', 'ISIC_0024346': 'content\\HAM10000_images\\ISIC_0024346.jpg', 'ISIC_0024347': 'content\\HAM10000_images\\ISIC_0024347.jpg', 'ISIC_0024348': 'content\\HAM10000_images\\ISIC_0024348.jpg', 'ISIC_0024349': 'content\\HAM10000_images\\ISIC_0024349.jpg', 'ISIC_0024350': 'content\\HAM10000_images\\ISIC_0024350.jpg', 'ISIC_0024351': 'content\\HAM10000_images\\ISIC_0024351.jpg', 'ISIC_0024352': 'content\\HAM10000_images\\ISIC_0024352.jpg', 'ISIC_0024353': 'content\\HAM10000_images\\ISIC_0024353.jpg', 'ISIC_0024354': 'content\\HAM10000_images\\ISIC_0024354.jpg', 'ISIC_0024355': 'content\\HAM10000_images\\ISIC_0024355.jpg', 'ISIC_0024356': 'content\\HAM10000_images\\ISIC_0024356.jpg', 'ISIC_0024357': 'content\\HAM10000_images\\ISIC_0024357.jpg', 'ISIC_0024358': 'content\\HAM10000_images\\ISIC_0024358.jpg', 'ISIC_0024359': 'content\\HAM10000_images\\ISIC_0024359.jpg', 'ISIC_0024360': 'content\\HAM10000_images\\ISIC_0024360.jpg', 'ISIC_0024361': 'content\\HAM10000_images\\ISIC_0024361.jpg', 'ISIC_0024362': 'content\\HAM10000_images\\ISIC_0024362.jpg', 'ISIC_0024363': 'content\\HAM10000_images\\ISIC_0024363.jpg', 'ISIC_0024364': 'content\\HAM10000_images\\ISIC_0024364.jpg', 'ISIC_0024365': 'content\\HAM10000_images\\ISIC_0024365.jpg', 'ISIC_0024366': 'content\\HAM10000_images\\ISIC_0024366.jpg', 'ISIC_0024367': 'content\\HAM10000_images\\ISIC_0024367.jpg', 'ISIC_0024368': 'content\\HAM10000_images\\ISIC_0024368.jpg', 'ISIC_0024369': 'content\\HAM10000_images\\ISIC_0024369.jpg', 'ISIC_0024370': 'content\\HAM10 ...

# %%
print(os.path.join(raw_images, '*', '*.jpg'))
# Out:
# content\HAM10000_images\*\*.jpg

# %%
df['path'] = df['image_id'].map(imageid_path_dict.get)
df['cell_type'] = df['dx'].map(lesion_type_dict.get)
df['cell_type_idx'] = pd.Categorical(df['cell_type']).codes

# %%
print(df.keys())
# Out:
# Index(['lesion_id', 'image_id', 'dx', 'dx_type', 'age', 'sex', 'localization',
#        'dataset', 'path', 'cell_type', 'cell_type_idx'],
#       dtype='object')

# %%
df
# Out:
#          lesion_id      image_id     dx dx_type   age     sex localization  \
# 0      HAM_0000118  ISIC_0027419    bkl   histo  80.0    male        scalp
# 1      HAM_0000118  ISIC_0025030    bkl   histo  80.0    male        scalp
# 2      HAM_0002730  ISIC_0026769    bkl   histo  80.0    male        scalp
# 3      HAM_0002730  ISIC_0025661    bkl   histo  80.0    male        scalp
# 4      HAM_0001466  ISIC_0031633    bkl   histo  75.0    male          ear
# ...            ...           ...    ...     ...   ...     ...          ...
# 10010  HAM_0002867  ISIC_0033084  akiec   histo  40.0    male      abdomen
# 10011  HAM_0002867  ISIC_0033550  akiec   histo  40.0    male      abdomen
# 10012  HAM_0002867  ISIC_0033536  akiec   histo  40.0    male      abdomen
# 10013  HAM_0000239  ISIC_0032854  akiec   histo  80.0    male         face
# 10014  HAM_0003521  ISIC_0032258    mel   histo  70.0  female         back
#
#             dataset                                      path  \
# 0      vidir_modern  content\HAM10000_images\ISIC_0027419.jpg
# 1      vidir_modern  content\HAM10000_images\ISIC_0025030.jpg
# 2      vidir_modern  content\HAM10000_images\ISIC_0026769.jpg
# 3      vidir_modern  content\HAM10000_images\ISIC_0025661.jpg
# 4      vidir_modern  content\HAM10000_images\ISIC_0031633.jpg
# ...             ...                                       ...
# 10010  vidir_modern  content\HAM10000_images\ISIC_0033084.jpg
# 10011  vidir_modern  content\HAM10000_images\ISIC_0033550.jpg
# 10012  vidir_modern  content\HAM10000_images\ISIC_0033536.jpg
# 10013  vidir_modern  content\HAM10000_images\ISIC_0032854.jpg
# 10014  vidir_modern  content\HAM10000_images\ISIC_0032258.jpg
#
#                            cell_type  cell_type_idx
# 0      Bening keratosis-like lesions              2
# 1      Bening keratosis-like lesions              2
# 2      Bening keratosis-like lesions              2
# 3      Bening keratosis-like lesions              2
# 4      Bening keratosis-like lesions              2
# ...                              ...            ...
# 10010              Actinic keratoses              0
# 10011              Actinic keratoses              0
# 10012              Actinic keratoses              0
# 10013              Actinic keratoses              0
# 10014                       Melanoma              5
#
# [10015 rows x 11 columns]

# %%
df.isna().sum()
# Out:
# lesion_id         0
# image_id          0
# dx                0
# dx_type           0
# age              57
# sex               0
# localization      0
# dataset           0
# path              0
# cell_type         0
# cell_type_idx     0
# dtype: int64

# %%
df['age'].mean()
# Out:
# 51.863828077927295

# %%
ax = sns.countplot(x = 'sex', data = df)
plt.title('Gender wise distribution')
plt.xticks(rotation=45)
plt.show()

# %%
df['sex'].value_counts()
# Out:
# male       5406
# female     4552
# unknown      57
# Name: sex, dtype: int64

# %%
sns.set_style('whitegrid')
fig,axes = plt.subplots(figsize=(12,8))
ax = sns.countplot(x='cell_type',data=df, order = df['cell_type'].value_counts().index, palette = 'Paired')
for container in ax.containers:
    ax.bar_label(container)
plt.title('Cell Types Skin Cancer Affected patients')
plt.xticks(rotation=45)
plt.show()

# %%
sns.set_style('whitegrid')
fig,axes = plt.subplots(figsize=(12,8))
ax = sns.countplot(x='cell_type', hue='sex', data = df)
plt.title('Cell types frequencies')
plt.xticks(rotation=90)
plt.show()

# %%
sns.set_style('whitegrid')
fig,axes = plt.subplots(figsize=(12,8))
ax = sns.countplot(x='dx_type', data=df)
plt.title('cell types frequencies')
plt.xticks(rotation=45)
plt.show()

# %%
sns.set_style('whitegrid')
fig,ax = plt.subplots(figsize=(12,8))
ax = sns.countplot(x='dx_type', hue = 'sex', data = df)
plt.title('cell types frequencies')
plt.xticks(rotation=45)
plt.show()

# %%
sns.set_style('whitegrid')
fig,axis = plt.subplots(figsize=(12,8))
ax = sns.countplot(x='localization', data=df, order=df['localization'].value_counts().index, palette='crest')
plt.title('Localization Area Frequencies')
plt.xticks(rotation=45)
plt.show()

# %%
fig,axes = plt.subplots(figsize=(12,8))
ax = sns.countplot(x = 'localization', hue = 'sex', data = df, order = df['localization'].value_counts().index, palette='crest')
plt.title('Localization Area Frequencies')
plt.xticks(rotation=45)
plt.show()

# %%
sns.set_style('whitegrid')
fig,axes = plt.subplots(figsize=(12,8))
ax = sns.countplot(x = 'age', data = df)
plt.title('Age Histogram')
plt.xticks(rotation=90)
plt.show()

# %%
sns.set_style('whitegrid')
fig, axes = plt.subplots(figsize=(12,8))
ax = sns.histplot(data=df, x = 'age', hue = 'sex', multiple='stack')
plt.title('age histogram gender wiese')
plt.show()

# %%
sns.set_style('whitegrid')
fig,axes = plt.subplots(figsize=(12,8))
ax = sns.histplot(data=df, x='age',hue='cell_type',multiple='stack')
plt.title('Age Histogram Cell Type Wise')
plt.show()

# %%
sns.set_style('whitegrid')
fig,axes = plt.subplots(figsize=(12,8))
ax = sns.histplot(data=df, x='age',hue='localization',multiple='stack')
plt.title('Age Histogram Localization Area Wise')
plt.show()

# %%
# Function to read and resize images
def read_and_resize_image(image_path, size):
    img = cv2.imread(image_path)
    img = cv2.resize(img, size)
    return img

# %%
image_size = (64, 64)

# %%
# Apply the function to each image path in the 'path' column of the dataframe
df['image'] = df['path'].apply(lambda x: read_and_resize_image(x, image_size))

# %%
n_samples = 5
fig, m_axs = plt.subplots(7, n_samples, figsize = (4*n_samples, 3*7))
for n_axs, (type_name, type_rows) in zip(m_axs, df.sort_values(['cell_type']).groupby('cell_type')):
    n_axs[0].set_title(type_name)
    for c_ax, (_, c_row) in zip(n_axs, type_rows.sample(n_samples, random_state=1234).iterrows()):
        c_ax.imshow(c_row['image'])
        c_ax.axis('off')
fig.savefig('category_samples.png', dpi=300)

# %%
df['image'].map(lambda x: x.shape).value_counts()
# Out:
# (64, 64, 3)    10015
# Name: image, dtype: int64

# %%
from sklearn.model_selection import train_test_split
# Split the data into train and test sets
train_df, test_df = train_test_split(df, test_size=0.2, stratify=df['cell_type_idx'], random_state=42)

# %%
# Extract the image data and target labels for train and test sets
X_train = np.stack(train_df['image'].values)
y_train = train_df['cell_type_idx'].values
X_test = np.stack(test_df['image'].values)
y_test = test_df['cell_type_idx'].values

# %%
from keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout
from keras import Sequential
import tensorflow

model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(image_size[0], image_size[1], 3)))
model.add(MaxPool2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPool2D((2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(df['cell_type_idx'].unique()), activation='softmax'))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 from keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout
#       2 from keras import Sequential
#       3 import tensorflow
#
# File ~\PycharmProjects\COM3025-CW\venv\lib\site-packages\keras\__init__.py:21
#      15 """Implementation of the Keras API, the high-level API of TensorFlow.
#      16
#      17 Detailed documentation and user guides are available at
#      18 [keras.io](https://keras.io).
#      19 """
#      20 from keras import distribute
# ---> 21 from keras import models
#      22 from keras.engine.input_layer import Input
#      23 from keras.engine.sequential import Sequential
#
# File ~\PycharmProjects\COM3025-CW\venv\lib\site-packages\keras\models\__init__.py:18
#       1 # Copyright 2022 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """Keras models API."""
# ---> 18 from keras.engine.functional import Functional
#      19 from keras.engine.sequential import Sequential
#      20 from keras.engine.training import Model
#
# File ~\PycharmProjects\COM3025-CW\venv\lib\site-packages\keras\engine\functional.py:24
#      21 import itertools
#      22 import warnings
# ---> 24 import tensorflow.compat.v2 as tf
#      26 from keras import backend
#      27 from keras.dtensor import layout_map as layout_map_lib
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
model.compile(optimizer = 'adam', loss= 'sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(X_train, y_train, batch_size=32, epochs=3, validation_split=0.1)

# %%
# Use the trained model to make predictions on the test data
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)

# Calculate the accuracy
accuracy = np.mean(y_pred_classes == y_test) * 100
print(f'Test accuracy: {accuracy:.2f}%')

# %%
# Create a new DataFrame with 'lesion_id' and 'cell_type_dx' columns from the test data
result_df = pd.DataFrame({'lesion_id': test_df['lesion_id'], 'target': y_test})

# Save the DataFrame to a CSV file
result_df.to_csv('submission.csv', index=False)
